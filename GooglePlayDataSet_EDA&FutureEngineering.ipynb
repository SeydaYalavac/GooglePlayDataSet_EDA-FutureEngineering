# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("17-googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
## missing data
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## Veri tipi dönüşümleri

# %%
df["Reviews"].value_counts()
# Out:
# Reviews
# 0         596
# 1         272
# 2         214
# 3         175
# 4         137
#          ...
# 885         1
# 88486       1
# 603         1
# 1195        1
# 398307      1
# Name: count, Length: 6002, dtype: int64

# %%
df["Reviews"].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'],
#       shape=(6002,), dtype=object)

# %%
df["Reviews"].str.isnumeric().sum()
# Out:
# np.int64(10840)

# %%
df[~df["Reviews"].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_clean=df.copy()

# %%
df_clean=df_clean.drop(df_clean.index[10472])

# %%
df_clean["Reviews"].str.isnumeric().sum()
# Out:
# np.int64(10840)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.2+ MB

# %%
df_clean["Reviews"]=df_clean["Reviews"].astype(int)

# %%
df_clean.describe()
# Out:
#             Rating       Reviews
# count  9366.000000  1.084000e+04
# mean      4.191757  4.441529e+05
# std       0.515219  2.927761e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.477550e+04
# max       5.000000  7.815831e+07

# %%
df_clean["Size"].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 253k                     1
# 992k                     1
# 658k                     1
# 73k                      1
# 246k                     1
# Name: count, Length: 461, dtype: int64

# %%
df_clean["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %%
df_clean["Size"]=df_clean["Size"].str.replace("M","000")
df_clean["Size"]=df_clean["Size"].str.replace("k","")
df_clean["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
#        '7.3000', '9.1000', '55000', '23', '6.5000', '1.5000', '7.5000',
#        '51000', '41000', '48000', '8.5000', '46000', '8.3000', '4.3000',
#        '4.7000', '3.3000', '40000', '7.8000', '8.8000', '6.6000',
#        '5.1000', '61000', '66000', '79', '8.4000', '118', '44000', '695',
#        '1.6000', '6.2000', '18', '53000', '1.4000', '3.0000', '5.8000',
#        '3.8000', '9.6000', '45000', '63000', '49000', '77000', '4.4000',
#        '4.8000', '70000', '6.9000', '9.3000', '10.0000', '8.1000',
#        '36000', '84000', '97000', '2.0000', '1.9000', '1.8000', '5.3000',
#        '47000', '556', '526', '76000', '7.6000', '59000', '9.7000',
#        '78000', '72000', '43000', '7.7000', '6.3000', '334', '34000',
#        '93000', '65000', '79000', '100000', '58000', '50000', '68000',
#        '64000', '67000', '60000', '94000', '232', '99000', '624', '95000',
#        '8.5', '41', '292', '11', '80000', '1.7000', '74000', '62000',
#        '69000', '75000', '98000', '85000', '82000', '96000', '87000',
#        '71000', '86000', '91000', '81000', '92000', '83000', '88000',
#        '704', '862', '899', '378', '266', '375', '1.3000', '975', '980',
#        '4.1000', '89000', '696', '544', '525', '920', '779', '853', '720',
#        '713', '772', '318', '58', '241', '196', '857', '51', '953', '865',
#        '251', '930', '540', '313', '746', '203', '26', '314', '239',
#        '371', '220', '730', '756', '91', '293', '17', '74', '14', '317',
#        '78', '924', '902', '818', '81', '939', '169', '45', '475', '965',
#        '90000', '545', '61', '283', '655', '714', '93', '872', '121',
#        '322', '1.0000', '976', '172', '238', '549', '206', '954', '444',
#        '717', '210', '609', '308', '705', '306', '904', '473', '175',
#        '350', '383', '454', '421', '70', '812', '442', '842', '417',
#        '412', '459', '478', '335', '782', '721', '430', '429', '192',
#        '200', '460', '728', '496', '816', '414', '506', '887', '613',
#        '243', '569', '778', '683', '592', '319', '186', '840', '647',
#        '191', '373', '437', '598', '716', '585', '982', '222', '219',
#        '55', '948', '323', '691', '511', '951', '963', '25', '554', '351',
#        '27', '82', '208', '913', '514', '551', '29', '103', '898', '743',
#        '116', '153', '209', '353', '499', '173', '597', '809', '122',
#        '411', '400', '801', '787', '237', '50', '643', '986', '97', '516',
#        '837', '780', '961', '269', '20', '498', '600', '749', '642',
#        '881', '72', '656', '601', '221', '228', '108', '940', '176', '33',
#        '663', '34', '942', '259', '164', '458', '245', '629', '28', '288',
#        '775', '785', '636', '916', '994', '309', '485', '914', '903',
#        '608', '500', '54', '562', '847', '957', '688', '811', '270', '48',
#        '329', '523', '921', '874', '981', '784', '280', '24', '518',
#        '754', '892', '154', '860', '364', '387', '626', '161', '879',
#        '39', '970', '170', '141', '160', '144', '143', '190', '376',
#        '193', '246', '73', '658', '992', '253', '420', '404', '470',
#        '226', '240', '89', '234', '257', '861', '467', '157', '44', '676',
#        '67', '552', '885', '1020', '582', '619'], dtype=object)

# %%
df_clean["Size"]=df_clean["Size"].replace("Varies with device",np.nan)

# %%
df_clean["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', nan, '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
#        '23', '6.5000', '1.5000', '7.5000', '51000', '41000', '48000',
#        '8.5000', '46000', '8.3000', '4.3000', '4.7000', '3.3000', '40000',
#        '7.8000', '8.8000', '6.6000', '5.1000', '61000', '66000', '79',
#        '8.4000', '118', '44000', '695', '1.6000', '6.2000', '18', '53000',
#        '1.4000', '3.0000', '5.8000', '3.8000', '9.6000', '45000', '63000',
#        '49000', '77000', '4.4000', '4.8000', '70000', '6.9000', '9.3000',
#        '10.0000', '8.1000', '36000', '84000', '97000', '2.0000', '1.9000',
#        '1.8000', '5.3000', '47000', '556', '526', '76000', '7.6000',
#        '59000', '9.7000', '78000', '72000', '43000', '7.7000', '6.3000',
#        '334', '34000', '93000', '65000', '79000', '100000', '58000',
#        '50000', '68000', '64000', '67000', '60000', '94000', '232',
#        '99000', '624', '95000', '8.5', '41', '292', '11', '80000',
#        '1.7000', '74000', '62000', '69000', '75000', '98000', '85000',
#        '82000', '96000', '87000', '71000', '86000', '91000', '81000',
#        '92000', '83000', '88000', '704', '862', '899', '378', '266',
#        '375', '1.3000', '975', '980', '4.1000', '89000', '696', '544',
#        '525', '920', '779', '853', '720', '713', '772', '318', '58',
#        '241', '196', '857', '51', '953', '865', '251', '930', '540',
#        '313', '746', '203', '26', '314', '239', '371', '220', '730',
#        '756', '91', '293', '17', '74', '14', '317', '78', '924', '902',
#        '818', '81', '939', '169', '45', '475', '965', '90000', '545',
#        '61', '283', '655', '714', '93', '872', '121', '322', '1.0000',
#        '976', '172', '238', '549', '206', '954', '444', '717', '210',
#        '609', '308', '705', '306', '904', '473', '175', '350', '383',
#        '454', '421', '70', '812', '442', '842', '417', '412', '459',
#        '478', '335', '782', '721', '430', '429', '192', '200', '460',
#        '728', '496', '816', '414', '506', '887', '613', '243', '569',
#        '778', '683', '592', '319', '186', '840', '647', '191', '373',
#        '437', '598', '716', '585', '982', '222', '219', '55', '948',
#        '323', '691', '511', '951', '963', '25', '554', '351', '27', '82',
#        '208', '913', '514', '551', '29', '103', '898', '743', '116',
#        '153', '209', '353', '499', '173', '597', '809', '122', '411',
#        '400', '801', '787', '237', '50', '643', '986', '97', '516', '837',
#        '780', '961', '269', '20', '498', '600', '749', '642', '881', '72',
#        '656', '601', '221', '228', '108', '940', '176', '33', '663', '34',
#        '942', '259', '164', '458', '245', '629', '28', '288', '775',
#        '785', '636', '916', '994', '309', '485', '914', '903', '608',
#        '500', '54', '562', '847', '957', '688', '811', '270', '48', '329',
#        '523', '921', '874', '981', '784', '280', '24', '518', '754',
#        '892', '154', '860', '364', '387', '626', '161', '879', '39',
#        '970', '170', '141', '160', '144', '143', '190', '376', '193',
#        '246', '73', '658', '992', '253', '420', '404', '470', '226',
#        '240', '89', '234', '257', '861', '467', '157', '44', '676', '67',
#        '552', '885', '1020', '582', '619'], dtype=object)

# %%
df_clean["Size"]=df_clean["Size"].astype(float)
df_clean["Size"]
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
df_clean.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# ## Karakter Temizlikleri

# %%
df_clean.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size     Installs  Type Price Content Rating  \
# 10836     4.5       38  53000.0       5,000+  Free     0       Everyone
# 10837     5.0        4      3.6         100+  Free     0       Everyone
# 10838     NaN        3      9.5       1,000+  Free     0       Everyone
# 10839     4.5      114      NaN       1,000+  Free     0     Mature 17+
# 10840     4.5   398307  19000.0  10,000,000+  Free     0       Everyone
#
#                   Genres      Last Updated         Current Ver  \
# 10836          Education     July 25, 2017                1.48
# 10837          Education      July 6, 2018                 1.0
# 10838            Medical  January 20, 2017                 1.0
# 10839  Books & Reference  January 19, 2015  Varies with device
# 10840          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
df_clean["Installs"].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
df_clean["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df_clean["Price"].value_counts()
# Out:
# Price
# 0          10040
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
#            ...
# $3.61          1
# $394.99        1
# $1.26          1
# $1.20          1
# $1.04          1
# Name: count, Length: 92, dtype: int64

# %%
df_clean["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
chars_to_remove=["+",",","$"]
cols_to_clean=["Installs","Price"]

# %%
for item in chars_to_remove:
    for cols in cols_to_clean:
        df_clean[cols]=df_clean[cols].str.replace(item,"")

# %%
df_clean["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_clean["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_clean["Price"]=df_clean["Price"].astype(float)

# %%
df_clean["Installs"]=df_clean["Installs"].astype(int)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
df_clean.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ## Tarihlerle çalışmak

# %%
df_clean["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
df_clean["Last Updated"]=pd.to_datetime(df_clean["Last Updated"])
df_clean.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
df_clean["Day"]=df_clean["Last Updated"].dt.day
df_clean["Month"]=df_clean["Last Updated"].dt.day
df_clean["Year"]=df_clean["Last Updated"].dt.day

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ## Dağılım Grafikleri

# %%
df_clean[df_clean.duplicated("App")].shape#tekrar eden saıyları gösterir
# Out:
# (1181, 16)

# %%
df_clean.drop_duplicates(subset=["App"],keep="first")
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int32
#  14  Month           10840 non-null  int32
#  15  Year            10840 non-null  int32
# dtypes: datetime64[ns](1), float64(3), int32(3), int64(2), object(7)
# memory usage: 1.3+ MB

# %%
numeric_features=[feature for feature in df_clean.columns if df_clean[feature].dtype !="O"]
categorical_features=[feature for feature in df_clean.columns if df_clean[feature].dtype =="O"]

# %%
print(numeric_features)
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Last Updated', 'Day', 'Month', 'Year']

# %%
print(categorical_features)
# Out:
# ['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver']

# %%
df_clean["Android Ver"].dtype
# Out:
# dtype('O')

# %%
plt.figure(figsize=(15,10))

for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df_clean[numeric_features[i]],color="b",fill=True)
    plt.xlabel(numeric_features[i])
    plt.tight_layout()
plt.show()

# %% [markdown]
# # Karşımıza çıkabilecek mülakat soruları

# %%
df_clean.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#    Day  Month  Year
# 0    7      7     7
# 1   15     15    15
# 2    1      1     1
# 3    8      8     8
# 4   20     20    20

# %%
plt.figure(figsize=(15,5))
category=["Type","Content Rating"]
for i in range(0,len(category)):
    plt.subplot(1,2,i+1)
    sns.countplot(x=df_clean[category[i]],fill=True)
    plt.xlabel(category[i])
    plt.tight_layout()
plt.show()

# %%
df_clean.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#    Day  Month  Year
# 0    7      7     7
# 1   15     15    15
# 2    1      1     1
# 3    8      8     8
# 4   20     20    20

# %%
df_clean["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
df_clean["Category"].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# COMICS                   60
# PARENTING                60
# BEAUTY                   53
# Name: count, dtype: int64

# %%
# top app categories by installment

# %%
df_clean.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10836     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10837     5.0        4      3.6       100  Free    0.0       Everyone
# 10838     NaN        3      9.5      1000  Free    0.0       Everyone
# 10839     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# 10836          Education   2017-07-25                1.48          4.1 and up
# 10837          Education   2018-07-06                 1.0          4.1 and up
# 10838            Medical   2017-01-20                 1.0          2.2 and up
# 10839  Books & Reference   2015-01-19  Varies with device  Varies with device
# 10840          Lifestyle   2018-07-25  Varies with device  Varies with device
#
#        Day  Month  Year
# 10836   25     25    25
# 10837    6      6     6
# 10838   20     20    20
# 10839   19     19    19
# 10840   25     25    25

# %%
df_clean.groupby(["Category"])["Installs"].mean()
# Out:
# Category
# ART_AND_DESIGN         1.912894e+06
# AUTO_AND_VEHICLES      6.250613e+05
# BEAUTY                 5.131519e+05
# BOOKS_AND_REFERENCE    8.318050e+06
# BUSINESS               2.178076e+06
# COMICS                 9.347692e+05
# COMMUNICATION          8.435989e+07
# DATING                 1.129533e+06
# EDUCATION              5.586231e+06
# ENTERTAINMENT          1.925611e+07
# EVENTS                 2.495806e+05
# FAMILY                 5.201959e+06
# FINANCE                2.395215e+06
# FOOD_AND_DRINK         2.156683e+06
# GAME                   3.066960e+07
# HEALTH_AND_FITNESS     4.642441e+06
# HOUSE_AND_HOME         1.917187e+06
# LIBRARIES_AND_DEMO     7.411284e+05
# LIFESTYLE              1.407444e+06
# MAPS_AND_NAVIGATION    5.286729e+06
# MEDICAL                1.150269e+05
# NEWS_AND_MAGAZINES     2.648876e+07
# PARENTING              5.253518e+05
# PERSONALIZATION        5.932385e+06
# PHOTOGRAPHY            3.011417e+07
# PRODUCTIVITY           3.343418e+07
# SHOPPING               1.249173e+07
# SOCIAL                 4.769447e+07
# SPORTS                 4.560350e+06
# TOOLS                  1.358573e+07
# TRAVEL_AND_LOCAL       2.662359e+07
# VIDEO_PLAYERS          3.555430e+07
# WEATHER                5.196348e+06
# Name: Installs, dtype: float64

# %%
df_clean.groupby(["Category"])["Installs"].sum()
# Out:
# Category
# ART_AND_DESIGN           124338100
# AUTO_AND_VEHICLES         53130211
# BEAUTY                    27197050
# BOOKS_AND_REFERENCE     1921469576
# BUSINESS                1001914865
# COMICS                    56086150
# COMMUNICATION          32647276251
# DATING                   264310807
# EDUCATION                871452000
# ENTERTAINMENT           2869160000
# EVENTS                    15973161
# FAMILY                 10258263505
# FINANCE                  876648734
# FOOD_AND_DRINK           273898751
# GAME                   35086024415
# HEALTH_AND_FITNESS      1583072512
# HOUSE_AND_HOME           168712461
# LIBRARIES_AND_DEMO        62995910
# LIFESTYLE                537643539
# MAPS_AND_NAVIGATION      724281890
# MEDICAL                   53257437
# NEWS_AND_MAGAZINES      7496317760
# PARENTING                 31521110
# PERSONALIZATION         2325494782
# PHOTOGRAPHY            10088247655
# PRODUCTIVITY           14176091369
# SHOPPING                3247848785
# SOCIAL                 14069867902
# SPORTS                  1751174498
# TOOLS                  11452771915
# TRAVEL_AND_LOCAL        6868887146
# VIDEO_PLAYERS           6222002720
# WEATHER                  426100520
# Name: Installs, dtype: int64

# %%
df_clean.groupby(["Category"])["Installs"].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   35086024415
# COMMUNICATION          32647276251
# PRODUCTIVITY           14176091369
# SOCIAL                 14069867902
# TOOLS                  11452771915
# FAMILY                 10258263505
# PHOTOGRAPHY            10088247655
# NEWS_AND_MAGAZINES      7496317760
# TRAVEL_AND_LOCAL        6868887146
# VIDEO_PLAYERS           6222002720
# SHOPPING                3247848785
# ENTERTAINMENT           2869160000
# PERSONALIZATION         2325494782
# BOOKS_AND_REFERENCE     1921469576
# SPORTS                  1751174498
# HEALTH_AND_FITNESS      1583072512
# BUSINESS                1001914865
# FINANCE                  876648734
# EDUCATION                871452000
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                537643539
# WEATHER                  426100520
# FOOD_AND_DRINK           273898751
# DATING                   264310807
# HOUSE_AND_HOME           168712461
# ART_AND_DESIGN           124338100
# LIBRARIES_AND_DEMO        62995910
# COMICS                    56086150
# MEDICAL                   53257437
# AUTO_AND_VEHICLES         53130211
# PARENTING                 31521110
# BEAUTY                    27197050
# EVENTS                    15973161
# Name: Installs, dtype: int64

# %%
df_cat_installs = df_clean.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()

df_cat_installs["Installs"] = df_cat_installs["Installs"] / 1000

# %%
df_cat_installs
# Out:
#                Category      Installs
# 0                  GAME  3.508602e+07
# 1         COMMUNICATION  3.264728e+07
# 2          PRODUCTIVITY  1.417609e+07
# 3                SOCIAL  1.406987e+07
# 4                 TOOLS  1.145277e+07
# 5                FAMILY  1.025826e+07
# 6           PHOTOGRAPHY  1.008825e+07
# 7    NEWS_AND_MAGAZINES  7.496318e+06
# 8      TRAVEL_AND_LOCAL  6.868887e+06
# 9         VIDEO_PLAYERS  6.222003e+06
# 10             SHOPPING  3.247849e+06
# 11        ENTERTAINMENT  2.869160e+06
# 12      PERSONALIZATION  2.325495e+06
# 13  BOOKS_AND_REFERENCE  1.921470e+06
# 14               SPORTS  1.751174e+06
# 15   HEALTH_AND_FITNESS  1.583073e+06
# 16             BUSINESS  1.001915e+06
# 17              FINANCE  8.766487e+05
# 18            EDUCATION  8.714520e+05
# 19  MAPS_AND_NAVIGATION  7.242819e+05
# 20            LIFESTYLE  5.376435e+05
# 21              WEATHER  4.261005e+05
# 22       FOOD_AND_DRINK  2.738988e+05
# 23               DATING  2.643108e+05
# 24       HOUSE_AND_HOME  1.687125e+05
# 25       ART_AND_DESIGN  1.243381e+05
# 26   LIBRARIES_AND_DEMO  6.299591e+04
# 27               COMICS  5.608615e+04
# 28              MEDICAL  5.325744e+04
# 29    AUTO_AND_VEHICLES  5.313021e+04
# 30            PARENTING  3.152111e+04
# 31               BEAUTY  2.719705e+04
# 32               EVENTS  1.597316e+04

# %%
df_cat_installs["Installs"]=df_cat_installs["Installs"]/1000
df_cat_installs
# Out:
#                Category      Installs
# 0                  GAME  35086.024415
# 1         COMMUNICATION  32647.276251
# 2          PRODUCTIVITY  14176.091369
# 3                SOCIAL  14069.867902
# 4                 TOOLS  11452.771915
# 5                FAMILY  10258.263505
# 6           PHOTOGRAPHY  10088.247655
# 7    NEWS_AND_MAGAZINES   7496.317760
# 8      TRAVEL_AND_LOCAL   6868.887146
# 9         VIDEO_PLAYERS   6222.002720
# 10             SHOPPING   3247.848785
# 11        ENTERTAINMENT   2869.160000
# 12      PERSONALIZATION   2325.494782
# 13  BOOKS_AND_REFERENCE   1921.469576
# 14               SPORTS   1751.174498
# 15   HEALTH_AND_FITNESS   1583.072512
# 16             BUSINESS   1001.914865
# 17              FINANCE    876.648734
# 18            EDUCATION    871.452000
# 19  MAPS_AND_NAVIGATION    724.281890
# 20            LIFESTYLE    537.643539
# 21              WEATHER    426.100520
# 22       FOOD_AND_DRINK    273.898751
# 23               DATING    264.310807
# 24       HOUSE_AND_HOME    168.712461
# 25       ART_AND_DESIGN    124.338100
# 26   LIBRARIES_AND_DEMO     62.995910
# 27               COMICS     56.086150
# 28              MEDICAL     53.257437
# 29    AUTO_AND_VEHICLES     53.130211
# 30            PARENTING     31.521110
# 31               BEAUTY     27.197050
# 32               EVENTS     15.973161

# %%
#top 10 categories by install
df2=df_cat_installs.head(10)
plt.figure(figsize=(10,5))

sns.barplot(x="Installs",y="Category",data=df2)
plt.show()

# %%
#top 5 app in categories

# %%
df_app_category=df_clean.groupby(["Category","App"])["Installs"].sum().reset_index()

# %%
df_app_category=df_app_category.sort_values("Installs",ascending=False)

# %%
apps=["GAME","COMMUNICATION","TOOLS","PRODUCTIVITY","SOCIAL"]

plt.figure(figsize=(40,30))
for i,app in enumerate(apps):
    df2=df_app_category[df_app_category.Category==app]
    df2=df2.head(5)
    # print(df2)
    plt.subplot(3,2,i+1)
    sns.barplot(data=df2,x="Installs",y="App")
    plt.title(app,size=20)
plt.tight_layout()
plt.show()

# %%
df2
# Out:
#      Category            App    Installs
# 7999   SOCIAL      Instagram  4000000000
# 8064   SOCIAL       Snapchat  2000000000
# 7988   SOCIAL        Google+  2000000000
# 7963   SOCIAL       Facebook  2000000000
# 7965   SOCIAL  Facebook Lite  1000000000

# %%
#versiyon temizliği

# %%
#5 rating apps

# %%
rating_df=df_clean.groupby(["Category","Installs","App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
top_rated_apps=rating_df[rating_df["Rating"]==5.0]

# %%
top_rated_apps.shape
# Out:
# (269, 4)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int32
#  14  Month           10840 non-null  int32
#  15  Year            10840 non-null  int32
# dtypes: datetime64[ns](1), float64(3), int32(3), int64(2), object(7)
# memory usage: 1.3+ MB

# %%
df_clean["Android Ver"]
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10836            4.1 and up
# 10837            4.1 and up
# 10838            2.2 and up
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10840, dtype: object

# %%
df_clean["Android Ver"]=df_clean["Android Ver"].replace("and up","",regex=True)
#regex  regular expression bazı kriteri sağlayan şeyleri bulmaya yarıyor.

# %%
df_clean["Android Ver"]
# Out:
# 0                    4.0.3
# 1                    4.0.3
# 2                    4.0.3
# 3                      4.2
# 4                      4.4
#                 ...
# 10836                  4.1
# 10837                  4.1
# 10838                  2.2
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10840, dtype: object

# %%
df_clean["Android Ver"]=df_clean["Android Ver"].replace("Varies with device","",regex=True).replace("W","",regex=True).replace("",np.nan)

# %%
df_clean["Android Ver"].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        nan, '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ', '2.1 ', '7.0 ',
#        '5.1 ', '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ', '7.1 ',
#        '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ', '2.0.1 ',
#        '4.1 - 7.1.1', '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1', '5.0 - 7.1.1'],
#       dtype=object)

# %%
df_clean["Android Ver"].value_counts()
# Out:
# Android Ver
# 4.1              2451
# 4.0.3            1501
# 4.0              1375
# 4.4               992
# 2.3               652
# 5.0               601
# 4.2               394
# 2.3.3             281
# 2.2               244
# 4.3               243
# 3.0               241
# 2.1               134
# 1.6               116
# 6.0                60
# 7.0                42
# 3.2                36
# 2.0                32
# 5.1                24
# 1.5                20
# 3.1                10
# 2.0.1               7
# 8.0                 6
# 7.1                 3
# 5.0 - 8.0           2
# 4.0.3 - 7.1.1       2
# 1.0                 2
# 7.0 - 7.1.1         1
# 4.1 - 7.1.1         1
# 5.0 - 6.0           1
# 2.2 - 7.1.1         1
# 5.0 - 7.1.1         1
# Name: count, dtype: int64

# %%
df_clean[df_clean["Android Ver"].str.contains("-")==True]
# Out:
#                                  App         Category  Rating  Reviews  \
# 350           Web Browser & Explorer    COMMUNICATION     4.0    36901
# 352                       Browser 4G    COMMUNICATION     4.3   192948
# 1572                 ZenUI Safeguard        LIFESTYLE     4.5      100
# 2841   Photo Collage - Layout Editor      PHOTOGRAPHY     4.5   285788
# 3474                 ASUS Quick Memo     PRODUCTIVITY     4.5    23089
# 4151             Google Now Launcher            TOOLS     4.2   857215
# 7571            My Style CM 13 Theme  PERSONALIZATION     4.5      314
# 9310                       EF Jumper             GAME     NaN        4
# 10094             EY Catalyst Reader         BUSINESS     NaN        1
#
#           Size   Installs  Type  Price Content Rating           Genres  \
# 350        6.6    5000000  Free    0.0       Everyone    Communication
# 352        6.6   10000000  Free    0.0       Everyone    Communication
# 1572       7.1    1000000  Free    0.0       Everyone        Lifestyle
# 2841   46000.0   10000000  Free    0.0       Everyone      Photography
# 3474       1.6   10000000  Free    0.0       Everyone     Productivity
# 4151       7.9  100000000  Free    0.0       Everyone            Tools
# 7571   11000.0      10000  Free    0.0       Everyone  Personalization
# 9310       5.1        100  Free    0.0       Everyone           Arcade
# 10094      8.4          5  Free    0.0       Everyone         Business
#
#       Last Updated       Current Ver    Android Ver  Day  Month  Year
# 350     2018-07-04            11.8.6  4.0.3 - 7.1.1    4      4     4
# 352     2018-06-19            24.6.6  4.0.3 - 7.1.1   19     19    19
# 1572    2018-05-09   1.0.0.21_180410    7.0 - 7.1.1    9      9     9
# 2841    2017-12-04    1.8.0.170824_9      5.0 - 8.0    4      4     4
# 3474    2018-04-11  1.10.0.33_180403      5.0 - 8.0   11     11    11
# 4151    2017-12-07         1.4.large    4.1 - 7.1.1    7      7     7
# 7571    2016-09-08               1.9      5.0 - 6.0    8      8     8
# 9310    2017-07-13          Build 12    2.2 - 7.1.1   13     13    13
# 10094   2018-04-10             1.2.1    5.0 - 7.1.1   10     10    10

# %%
df_clean=df_clean[df_clean["Android Ver"].str.contains("-")==False]

# %%
df_clean["Android Ver"].value_counts()
# Out:
# Android Ver
# 4.1       2451
# 4.0.3     1501
# 4.0       1375
# 4.4        992
# 2.3        652
# 5.0        601
# 4.2        394
# 2.3.3      281
# 2.2        244
# 4.3        243
# 3.0        241
# 2.1        134
# 1.6        116
# 6.0         60
# 7.0         42
# 3.2         36
# 2.0         32
# 5.1         24
# 1.5         20
# 3.1         10
# 2.0.1        7
# 8.0          6
# 7.1          3
# 1.0          2
# Name: count, dtype: int64

# %% [markdown]
# ## Target Encoding

# %%
df_clean.tail()
# Out:
#                                     App  Category  Rating  Reviews     Size  \
# 10834                     FR Calculator    FAMILY     4.0        7      2.6
# 10835                          FR Forms  BUSINESS     NaN        0      9.6
# 10836                  Sya9a Maroc - FR    FAMILY     4.5       38  53000.0
# 10837  Fr. Mike Schmitz Audio Teachings    FAMILY     5.0        4      3.6
# 10838            Parkinson Exercices FR   MEDICAL     NaN        3      9.5
#
#        Installs  Type  Price Content Rating     Genres Last Updated  \
# 10834       500  Free    0.0       Everyone  Education   2017-06-18
# 10835        10  Free    0.0       Everyone   Business   2016-09-29
# 10836      5000  Free    0.0       Everyone  Education   2017-07-25
# 10837       100  Free    0.0       Everyone  Education   2018-07-06
# 10838      1000  Free    0.0       Everyone    Medical   2017-01-20
#
#       Current Ver Android Ver  Day  Month  Year
# 10834       1.0.0        4.1    18     18    18
# 10835       1.1.5        4.0    29     29    29
# 10836        1.48        4.1    25     25    25
# 10837         1.0        4.1     6      6     6
# 10838         1.0        2.2    20     20    20

# %%
mean_genres_installs=df_clean.groupby(["Genres"])["Installs"].mean()/1000000

# %%
mean_genres_installs
# Out:
# Genres
# Action                                   24.532777
# Action;Action & Adventure                 4.876281
# Adventure                                 5.422604
# Adventure;Action & Adventure             69.703846
# Adventure;Brain Games                     0.100000
#                                            ...
# Video Players & Editors                   8.061815
# Video Players & Editors;Creativity        5.000000
# Video Players & Editors;Music & Video     5.000000
# Weather                                   2.270176
# Word                                      6.166902
# Name: Installs, Length: 118, dtype: float64

# %%
mean_genres_installs=mean_genres_installs.to_dict()

# %%
mean_genres_installs
# Out:
# {'Action': 24.532776618911175,
#  'Action;Action & Adventure': 4.87628125,
#  'Adventure': 5.422604266666666,
#  'Adventure;Action & Adventure': 69.70384615384616,
#  'Adventure;Brain Games': 0.1,
#  'Adventure;Education': 10.0,
#  'Arcade': 49.252810941747576,
#  'Arcade;Action & Adventure': 3.229285785714286,
#  'Arcade;Pretend Play': 1.0,
#  'Art & Design': 1.8308589285714287,
#  'Art & Design;Action & Adventure': 0.1,
#  'Art & Design;Creativity': 0.3157142857142857,
#  'Art & Design;Pretend Play': 0.5,
#  'Auto & Vehicles': 0.5753873205128205,
#  'Beauty': 0.303941,
#  'Board': 3.9670764285714286,
#  'Board;Action & Adventure': 2.001666666666667,
#  'Board;Brain Games': 0.5254733333333333,
#  'Board;Pretend Play': 0.0001,
#  'Books & Reference': 0.7998128800000001,
#  'Books & Reference;Creativity': 0.0001,
#  'Books & Reference;Education': 0.0055,
#  'Business': 1.371011375598086,
#  'Card': 2.200636585365854,
#  'Card;Action & Adventure': 5.5,
#  'Card;Brain Games': 0.1,
#  'Casino': 2.980018918918919,
#  'Casual': 51.5251689010989,
#  'Casual;Action & Adventure': 6.1875625,
#  'Casual;Brain Games': 2.0854615384615385,
#  'Casual;Creativity': 6.0,
#  'Casual;Education': 0.67,
#  'Casual;Music & Video': 10.0,
#  'Casual;Pretend Play': 6.712033333333333,
#  'Comics': 0.430723,
#  'Comics;Creativity': 0.05,
#  'Communication': 23.24701778521127,
#  'Communication;Creativity': 0.5,
#  'Dating': 0.7761748063063063,
#  'Education': 0.6314510981963928,
#  'Education;Action & Adventure': 0.67,
#  'Education;Brain Games': 5.2002,
#  'Education;Creativity': 2.7583333333333333,
#  'Education;Education': 1.6576478048780487,
#  'Education;Music & Video': 0.4,
#  'Education;Pretend Play': 0.7358181818181818,
#  'Educational': 0.3562658857142857,
#  'Educational;Action & Adventure': 25.2625,
#  'Educational;Brain Games': 4.433333333333333,
#  'Educational;Creativity': 1.4011,
#  'Educational;Education': 1.587437435897436,
#  'Educational;Pretend Play': 10.37711052631579,
#  'Entertainment': 3.1345545732368896,
#  'Entertainment;Action & Adventure': 2.3333333333333335,
#  'Entertainment;Brain Games': 3.314285714285714,
#  'Entertainment;Creativity': 4.0,
#  'Entertainment;Education': 1.0,
#  'Entertainment;Music & Video': 12.7,
#  'Entertainment;Pretend Play': 3.0,
#  'Events': 0.09951861403508773,
#  'Finance': 1.0828518658146966,
#  'Food & Drink': 1.7542596116504856,
#  'Health & Fitness': 3.3526563880597013,
#  'Health & Fitness;Action & Adventure': 1.0,
#  'Health & Fitness;Education': 0.1,
#  'House & Home': 1.1045950147058825,
#  'Libraries & Demo': 0.7548281707317074,
#  'Lifestyle': 1.1834926828571428,
#  'Lifestyle;Education': 0.1,
#  'Lifestyle;Pretend Play': 10.0,
#  'Maps & Navigation': 1.6825444545454546,
#  'Medical': 0.11306361503416858,
#  'Music': 12.862880952380952,
#  'Music & Audio;Music & Video': 0.5,
#  'Music;Music & Video': 3.367,
#  'News & Magazines': 19.28684890909091,
#  'Parenting': 0.4236615909090909,
#  'Parenting;Brain Games': 1.0,
#  'Parenting;Education': 0.45285714285714285,
#  'Parenting;Music & Video': 0.342,
#  'Personalization': 2.729512170940171,
#  'Photography': 12.999991534296027,
#  'Productivity': 11.429288503144653,
#  'Puzzle': 12.079542108695652,
#  'Puzzle;Action & Adventure': 31.02,
#  'Puzzle;Brain Games': 8.17421052631579,
#  'Puzzle;Creativity': 0.75,
#  'Puzzle;Education': 0.1,
#  'Racing': 21.20901404255319,
#  'Racing;Action & Adventure': 10.613,
#  'Racing;Pretend Play': 1.0,
#  'Role Playing': 3.2826229906542053,
#  'Role Playing;Action & Adventure': 6.22,
#  'Role Playing;Brain Games': 10.0,
#  'Role Playing;Education': 0.0001,
#  'Role Playing;Pretend Play': 4.24,
#  'Shopping': 7.920725780487805,
#  'Simulation': 3.7057120833333337,
#  'Simulation;Action & Adventure': 6.7272727272727275,
#  'Simulation;Education': 0.20016666666666666,
#  'Simulation;Pretend Play': 0.5275,
#  'Social': 5.1852995545454545,
#  'Sports': 7.040619936416184,
#  'Sports;Action & Adventure': 2.675,
#  'Strategy': 19.39730297029703,
#  'Strategy;Action & Adventure': 0.55,
#  'Strategy;Creativity': 1.0,
#  'Strategy;Education': 0.5,
#  'Tools': 4.767368526244954,
#  'Travel & Local': 3.391748212121212,
#  'Travel & Local;Action & Adventure': 0.1,
#  'Trivia': 3.3843781578947367,
#  'Trivia;Education': 0.0001,
#  'Video Players & Editors': 8.061814929577466,
#  'Video Players & Editors;Creativity': 5.0,
#  'Video Players & Editors;Music & Video': 5.0,
#  'Weather': 2.2701757894736843,
#  'Word': 6.166902}

# %%
df_clean["Genres Encoded"]=df_clean["Genres"].map(mean_genres_installs)

# %%
df_clean["Genres Encoded"]
# Out:
# 0        1.830859
# 1        0.500000
# 2        1.830859
# 3        1.830859
# 4        0.315714
#            ...
# 10834    0.631451
# 10835    1.371011
# 10836    0.631451
# 10837    0.631451
# 10838    0.113064
# Name: Genres Encoded, Length: 9467, dtype: float64
